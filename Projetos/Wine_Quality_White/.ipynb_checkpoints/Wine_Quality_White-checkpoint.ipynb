# %%
import pandas as pd
import matplotlib.pyplot as plt

wine = pd.read_csv("winequality-white.csv", sep=';')

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train_set, test_set = train_test_split(wine, test_size=0.2, random_state=42)
x_train = train_set.drop("quality", axis=1)
x_train_scaled = scaler.fit_transform(x_train)
y_train = train_set["quality"]
x_test = test_set.drop("quality", axis=1)
x_test_scaled = scaler.transform(x_test)
y_test = test_set["quality"]

# %%
from sklearn.neural_network import MLPClassifier

mlpc = MLPClassifier(max_iter=3000, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'hidden_layer_sizes': [
        (50,),               # 1 camada oculta com 50 neurônios
        (100,),              # 1 camada oculta com 100 neurônios
        (100, 50),           # 2 camadas: 100 + 50 neurônios
        (150, 100, 50),      # 3 camadas: 150 + 100 + 50 neurônios
    ],
    'activation': ['relu', 'tanh', 'logistic'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001],
    'learning_rate_init': [0.001, 0.01]
}

gridSearch = GridSearchCV(mlpc, param_grid, cv = 5, scoring="accuracy", n_jobs=-1)

# %%
gridSearch.fit(x_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, estimator=MLPClassifier(max_iter=3000, random_state=42),
#              n_jobs=-1,
#              param_grid={'activation': ['relu', 'tanh', 'logistic'],
#                          'alpha': [0.0001, 0.001],
#                          'hidden_layer_sizes': [(50,), (100,), (100, 50),
#                                                 (150, 100, 50)],
#                          'learning_rate_init': [0.001, 0.01],
#                          'solver': ['adam', 'sgd']},
#              scoring='accuracy')

# %%
gridSearch.best_score_
# Out:
# np.float64(0.6033632418484636)

# %%
mlpc_best = gridSearch.best_estimator_
y_predict = mlpc_best.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_predict, y_test)
print(accuracy)
# Out:
# 0.639795918367347

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Descubra todos os rótulos possíveis no seu conjunto (ex: de 3 a 8)
classes_possiveis = sorted(set(y_test) | set(y_predict))

# Calcula a matriz de confusão com labels explícitos
cm = confusion_matrix(y_test, y_predict, labels=classes_possiveis)

# Exibe corretamente com os mesmos labels
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes_possiveis)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_predict)
print(f"Mean Absolute Error: {mae:.2f}") #Acurácia de 64% pode parecer baixa, mas utilizando o MAE podemos ver que o modelo
                                        #erra em média apenas 0.38 pontos da verdadeira nota do vinho
# Out:
# Mean Absolute Error: 0.43

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_predict)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 0.63
